# %%
using Plots
gr()
# Out:
# Plots.GRBackend()

# %%
L = 1.
n = 101
h = L/(n-1)
println("h = $h")
stp = h
gp = 10h:10h:(L-h)
scatter([(i,j) for i in gp for j in gp], aspect_ratio=1, label="", 
                size=(900,900), xlims=(0.,1.), ylims=(0.,1.),
                xticks=[i for i in 0.0:0.1:1.0], yticks=[i for i in 0.0:0.1:1.0])
# Out:
# h = 0.01
